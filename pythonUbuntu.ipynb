# %%
import os
import sys
import urllib.request
import json

client_id = "yawK8bRLSL6ulLDQ6uvp"
client_secret = "7DkG6WxzbS"
encText = urllib.parse.quote("이태원 녹사평 맛집")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
    #jsonString = json.dumps(response_body.decode('utf-8'),indent=4)
    #print(jsonString)
    dict = json.loads(response_body.decode('utf-8'))
    print(dict['items'])
    for a in dict['items']:
        print("\n")
        print("title :" + a['title'])
        print("\n")
        print("bloggername :"+ a['bloggername'])
        print("\n")
        print("link : " + a['bloggerlink'])
        print("\n")
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 14 May 2019 18:47:57 +0900",
# "total": 28439,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>이태원</b> 고기집 스테이크에 랍스터까지 모두 먹는 <b>녹사평</b> <b>맛집</b>",
# "link": "https:\/\/blog.naver.com\/dlgodms12?Redirect=Log&logNo=221502718707",
# "description": "친구가 얼마 전 동호회 모임으로 다녀온 <b>이태원 녹사평 맛집</b> 인데 리코타 치즈 샐러드도 나오고... 생각하는 이태원 고기집 중의 맛집 녹사평 맛집 이구나 싶은 느낌까지 들었었죠. 구겨지지 않게 걸어놓을 수... ",
# "bloggername": "깜뽕이들과 함께해용♡",
# "bloggerlink": "https://blog.naver.com/dlgodms12",
# "postdate": "20190401"
#
# },
# {
# "title": "<b>이태원</b> 양갈비 잘하는 <b>녹사평</b> <b>맛집</b> 미슐램 다녀옴!",
# "link": "https:\/\/blog.naver.com\/sinachoco?Redirect=Log&logNo=221414757646",
# "description": "<b>이태원</b> 양갈비 미슐램 <b>녹사평</b> <b>맛집</b> 연말을 맞아서 기회가 될 때마다 지인들을 만나 송년 기념 식사를 하고 있는 요즘인데요. 최근에 다녀온 곳은 삿포로식 양고기를 먹을 수 있는 <b>이태원</b> 미슐램이었어요.... ",
# "bloggername": "시나. 사진찍는 핸드메이더",
# "bloggerlink": "https://blog.naver.com/sinachoco",
# "postdate": "20181207"
#
# },
# {
# "title": "<b>녹사평</b> <b>맛집</b> 미슐램 :: <b>이태원</b> 양갈비 지존!",
# "link": "https:\/\/blog.naver.com\/jiyu1220?Redirect=Log&logNo=221414496977",
# "description": "아삭아삭한 파채가 가득 올라가 식감을 풍부하게 해 줍니다:) <b>녹사평</b> <b>맛집</b>:: <b>이태원</b> 양갈비 전문점 미슐램 가게에 들어서자마자 사장님이 환하게 웃으며 선한 얼굴로 맞이해 주어서 첫 인상이 굉장히 좋았어요.... ",
# "bloggername": "지유의 <일상기록소>",
# "bloggerlink": "https://blog.naver.com/jiyu1220",
# "postdate": "20181207"
#
# },
# {
# "title": "[<b>이태원</b>브런치] <b>녹사평</b>역<b>맛집</b> 캐나다 스타일 커넉스에... ",
# "link": "https:\/\/blog.naver.com\/wjsdmsgml7?Redirect=Log&logNo=221515443945",
# "description": "친구와도 지금 우리가 캐나다에 와있는것 같다며ㅋㅋㅋ, 이 순간 만큼은 캐나다에 있다고 생각하자고 깔깔댄게 생각나네요. 이상으로 <b>녹사평</b>역<b>맛집</b> / <b>이태원</b>브런치 커넉스 후기였습니다!",
# "bloggername": "해질녘 노을처럼",
# "bloggerlink": "https://blog.naver.com/wjsdmsgml7",
# "postdate": "20190416"
#
# },
# {
# "title": "[[<b>녹사평</b>역<b>맛집</b>/커넉스]] <b>이태원</b>펍 캐나다 레스토랑 브런치카페",
# "link": "https:\/\/blog.naver.com\/isthisheaven?Redirect=Log&logNo=221484905982",
# "description": "#커넉스 #CANUCKS #<b>이태원</b><b>맛집</b> #<b>녹사평</b>역<b>맛집</b> #<b>이태원</b>펍 #<b>이태원</b>브런치 <b>녹사평</b> <b>이태원</b> 캐나다 대표 레스토랑 에그베네딕트, 팬케익, 오믈렛 캐나다 브런치 <b>맛집</b> 서울 용산구 <b>이태원</b>로 145 1층의 올리브영건물 2층... ",
# "bloggername": "조안나 행복한 블로그",
# "bloggerlink": "https://blog.naver.com/isthisheaven",
# "postdate": "20190311"
#
# },
# {
# "title": "#<b>녹사평</b>/<b>이태원</b> <b>맛집</b> 네이키드윙즈",
# "link": "https:\/\/blog.naver.com\/h00000n?Redirect=Log&logNo=221303372144",
# "description": "<b>이태원</b> 치킨 윙 날개만 파는 전문점 네이키드윙즈 ***-****-**** 서울 용산구 <b>녹사평</b>대로 174-11(<b>이태원</b>동... 피자집인데 윙 <b>맛집</b>이다. 진짜 짱맛이다. https://m.blog.naver.com/h00000n/220361418571 '' 이만큼 윙을 사랑하는... ",
# "bloggername": "꼼지락꼼지락 훈2 블로그",
# "bloggerlink": "https://blog.naver.com/h00000n",
# "postdate": "20180621"
#
# },
# {
# "title": "<b>녹사평</b>역 <b>맛집</b> 커넉스 <b>이태원</b> 캐나다 푸틴",
# "link": "https:\/\/blog.naver.com\/angelhaniel?Redirect=Log&logNo=221517912997",
# "description": "<b>녹사평</b>역 <b>맛집</b> 커넉스 CANUCKS <b>이태원</b> 캐나다 푸틴 예전부터 너무너무 와보고 싶었던 <b>이태원</b>에 있는 캐나다 음식 전문점 커넉스. 전부터 얘기를 많이 들어서 늘 궁금했었는데 벼르고 벼르다가 드디어... ",
# "bloggername": "☆:*:Haniel in wonderland:*:☆",
# "bloggerlink": "https://blog.naver.com/angelhaniel",
# "postdate": "20190419"
#
# },
# {
# "title": "[<b>이태원</b>/<b>녹사평</b> <b>맛집</b>] 외쿡의 맛 그대로 '라이너스 바베큐'",
# "link": "https:\/\/blog.naver.com\/cosu1212?Redirect=Log&logNo=221318116256",
# "description": "시작해볼까요~ <b>이태원</b> <b>맛집</b> '라이너스 바베큐' 후기 가게는 <b>이태원</b>역과 <b>녹사평</b>역 중간 부분에 위치하고 있어요 저희는 <b>녹사평</b>역에서 나와서 길따라 걷고~ 골목따라 걸으니까 요로코롬 느낌 충만한 가게가... ",
# "bloggername": "연이로그",
# "bloggerlink": "https://blog.naver.com/cosu1212",
# "postdate": "20180713"
#
# },
# {
# "title": "<b>이태원</b> <b>맛집</b>, <b>녹사평</b>역 <b>맛집</b> 라이너스 바베큐",
# "link": "https:\/\/blog.naver.com\/kwonsista?Redirect=Log&logNo=221234232533",
# "description": "동생쩡이) <b>이태원</b> <b>맛집</b>, <b>녹사평</b>역 <b>맛집</b> 라이너스 바베큐 전화번호 : 02-790-2920 영업시간 : 11:00 ~ 22:30 (L.O 21:45) 앞에 줄 서있는 사람들 ㅋㅋㅋ 5시쯤 갔는데도 사람이 많다. 아직 저녁 시간이 아닌데..!! 태블릿을... ",
# "bloggername": "What We Want",
# "bloggerlink": "https://blog.naver.com/kwonsista",
# "postdate": "20180321"
#
# },
# {
# "title": "<b>이태원</b>/<b>녹사평</b><b>맛집</b> : 정통 뉴욕식피자 '지노스피자(GINOS... ",
# "link": "https:\/\/blog.naver.com\/2vivi?Redirect=Log&logNo=221231696614",
# "description": "생각하며 <b>이태원</b>으로 멤버들을 불렀고요 <b>녹사평</b>역 언덕 유관순길에 위치한 지노스피자 본관에... 잘하네요 #감튀<b>맛집</b> #지노스피자 헉!!!!!!!주문한 피자가 나왔는데 대박쓰. 엄청 거대해요 나중에 검색해보니... ",
# "bloggername": "나스나스한하루",
# "bloggerlink": "https://blog.naver.com/2vivi",
# "postdate": "20180318"
#
# }
# ]
# }
#
# [{'title': '<b>이태원</b> 고기집 스테이크에 랍스터까지 모두 먹는 <b>녹사평</b> <b>맛집</b>', 'link': 'https://blog.naver.com/dlgodms12?Redirect=Log&logNo=221502718707', 'description': '친구가 얼마 전 동호회 모임으로 다녀온 <b>이태원 녹사평 맛집</b> 인데 리코타 치즈 샐러드도 나오고... 생각하는 이태원 고기집 중의 맛집 녹사평 맛집 이구나 싶은 느낌까지 들었었죠. 구겨지지 않게 걸어놓을 수... ', 'bloggername': '깜뽕이들과 함께해용♡', 'bloggerlink': 'https://blog.naver.com/dlgodms12', 'postdate': '20190401'}, {'title': '<b>이태원</b> 양갈비 잘하는 <b>녹사평</b> <b>맛집</b> 미슐램 다녀옴!', 'link': 'https://blog.naver.com/sinachoco?Redirect=Log&logNo=221414757646', 'description': '<b>이태원</b> 양갈비 미슐램 <b>녹사평</b> <b>맛집</b> 연말을 맞아서 기회가 될 때마다 지인들을 만나 송년 기념 식사를 하고 있는 요즘인데요. 최근에 다녀온 곳은 삿포로식 양고기를 먹을 수 있는 <b>이태원</b> 미슐램이었어요.... ', 'bloggername': '시나. 사진찍는 핸드메이더', 'bloggerlink': 'https://blog.naver.com/sinachoco', 'postdate': '20181207'}, {'title': '<b>녹사평</b> <b>맛집</b> 미슐램 :: <b>이태원</b> 양갈비 지존!', 'link': 'https://blog.naver.com/jiyu1220?Redirect=Log&logNo=221414496977', 'description': '아삭아삭한 파채가 가득 올라가 식감을 풍부하게 해 줍니다:) <b>녹사평</b> <b>맛집</b>:: <b>이태원</b> 양갈비 전문점 미슐램 가게에 들어서자마자 사장님이 환하게 웃으며 선한 얼굴로 맞이해 주어서 첫 인상이 굉장히 좋았어요.... ', 'bloggername': '지유의 <일상기록소>', 'bloggerlink': 'https://blog.naver.com/jiyu1220', 'postdate': '20181207'}, {'title': '[<b>이태원</b>브런치] <b>녹사평</b>역<b>맛집</b> 캐나다 스타일 커넉스에... ', 'link': 'https://blog.naver.com/wjsdmsgml7?Redirect=Log&logNo=221515443945', 'description': '친구와도 지금 우리가 캐나다에 와있는것 같다며ㅋㅋㅋ, 이 순간 만큼은 캐나다에 있다고 생각하자고 깔깔댄게 생각나네요. 이상으로 <b>녹사평</b>역<b>맛집</b> / <b>이태원</b>브런치 커넉스 후기였습니다!', 'bloggername': '해질녘 노을처럼', 'bloggerlink': 'https://blog.naver.com/wjsdmsgml7', 'postdate': '20190416'}, {'title': '[[<b>녹사평</b>역<b>맛집</b>/커넉스]] <b>이태원</b>펍 캐나다 레스토랑 브런치카페', 'link': 'https://blog.naver.com/isthisheaven?Redirect=Log&logNo=221484905982', 'description': '#커넉스 #CANUCKS #<b>이태원</b><b>맛집</b> #<b>녹사평</b>역<b>맛집</b> #<b>이태원</b>펍 #<b>이태원</b>브런치 <b>녹사평</b> <b>이태원</b> 캐나다 대표 레스토랑 에그베네딕트, 팬케익, 오믈렛 캐나다 브런치 <b>맛집</b> 서울 용산구 <b>이태원</b>로 145 1층의 올리브영건물 2층... ', 'bloggername': '조안나 행복한 블로그', 'bloggerlink': 'https://blog.naver.com/isthisheaven', 'postdate': '20190311'}, {'title': '#<b>녹사평</b>/<b>이태원</b> <b>맛집</b> 네이키드윙즈', 'link': 'https://blog.naver.com/h00000n?Redirect=Log&logNo=221303372144', 'description': "<b>이태원</b> 치킨 윙 날개만 파는 전문점 네이키드윙즈 ***-****-**** 서울 용산구 <b>녹사평</b>대로 174-11(<b>이태원</b>동... 피자집인데 윙 <b>맛집</b>이다. 진짜 짱맛이다. https://m.blog.naver.com/h00000n/220361418571 '' 이만큼 윙을 사랑하는... ", 'bloggername': '꼼지락꼼지락 훈2 블로그', 'bloggerlink': 'https://blog.naver.com/h00000n', 'postdate': '20180621'}, {'title': '<b>녹사평</b>역 <b>맛집</b> 커넉스 <b>이태원</b> 캐나다 푸틴', 'link': 'https://blog.naver.com/angelhaniel?Redirect=Log&logNo=221517912997', 'description': '<b>녹사평</b>역 <b>맛집</b> 커넉스 CANUCKS <b>이태원</b> 캐나다 푸틴 예전부터 너무너무 와보고 싶었던 <b>이태원</b>에 있는 캐나다 음식 전문점 커넉스. 전부터 얘기를 많이 들어서 늘 궁금했었는데 벼르고 벼르다가 드디어... ', 'bloggername': '☆:*:Haniel in wonderland:*:☆', 'bloggerlink': 'https://blog.naver.com/angelhaniel', 'postdate': '20190419'}, {'title': "[<b>이태원</b>/<b>녹사평</b> <b>맛집</b>] 외쿡의 맛 그대로 '라이너스 바베큐'", 'link': 'https://blog.naver.com/cosu1212?Redirect=Log&logNo=221318116256', 'description': "시작해볼까요~ <b>이태원</b> <b>맛집</b> '라이너스 바베큐' 후기 가게는 <b>이태원</b>역과 <b>녹사평</b>역 중간 부분에 위치하고 있어요 저희는 <b>녹사평</b>역에서 나와서 길따라 걷고~ 골목따라 걸으니까 요로코롬 느낌 충만한 가게가... ", 'bloggername': '연이로그', 'bloggerlink': 'https://blog.naver.com/cosu1212', 'postdate': '20180713'}, {'title': '<b>이태원</b> <b>맛집</b>, <b>녹사평</b>역 <b>맛집</b> 라이너스 바베큐', 'link': 'https://blog.naver.com/kwonsista?Redirect=Log&logNo=221234232533', 'description': '동생쩡이) <b>이태원</b> <b>맛집</b>, <b>녹사평</b>역 <b>맛집</b> 라이너스 바베큐 전화번호 : 02-790-2920 영업시간 : 11:00 ~ 22:30 (L.O 21:45) 앞에 줄 서있는 사람들 ㅋㅋㅋ 5시쯤 갔는데도 사람이 많다. 아직 저녁 시간이 아닌데..!! 태블릿을... ', 'bloggername': 'What We Want', 'bloggerlink': 'https://blog.naver.com/kwonsista', 'postdate': '20180321'}, {'title': "<b>이태원</b>/<b>녹사평</b><b>맛집</b> : 정통 뉴욕식피자 '지노스피자(GINOS... ", 'link': 'https://blog.naver.com/2vivi?Redirect=Log&logNo=221231696614', 'description': '생각하며 <b>이태원</b>으로 멤버들을 불렀고요 <b>녹사평</b>역 언덕 유관순길에 위치한 지노스피자 본관에... 잘하네요 #감튀<b>맛집</b> # ...
#
#
# title :<b>이태원</b> 고기집 스테이크에 랍스터까지 모두 먹는 <b>녹사평</b> <b>맛집</b>
#
#
# bloggername :깜뽕이들과 함께해용♡
#
#
# link : https://blog.naver.com/dlgodms12
#
#
#
#
# title :<b>이태원</b> 양갈비 잘하는 <b>녹사평</b> <b>맛집</b> 미슐램 다녀옴!
#
#
# bloggername :시나. 사진찍는 핸드메이더
#
#
# link : https://blog.naver.com/sinachoco
#
#
#
#
# title :<b>녹사평</b> <b>맛집</b> 미슐램 :: <b>이태원</b> 양갈비 지존!
#
#
# bloggername :지유의 <일상기록소>
#
#
# link : https://blog.naver.com/jiyu1220
#
#
#
#
# title :[<b>이태원</b>브런치] <b>녹사평</b>역<b>맛집</b> 캐나다 스타일 커넉스에...
#
#
# bloggername :해질녘 노을처럼
#
#
# link : https://blog.naver.com/wjsdmsgml7
#
#
#
#
# title :[[<b>녹사평</b>역<b>맛집</b>/커넉스]] <b>이태원</b>펍 캐나다 레스토랑 브런치카페
#
#
# bloggername :조안나 행복한 블로그
#
#
# link : https://blog.naver.com/isthisheaven
#
#
#
#
# title :#<b>녹사평</b>/<b>이태원</b> <b>맛집</b> 네이키드윙즈
#
#
# bloggername :꼼지락꼼지락 훈2 블로그
#
#
# link : https://blog.naver.com/h00000n
#
#
#
#
# title :<b>녹사평</b>역 <b>맛집</b> 커넉스 <b>이태원</b> 캐나다 푸틴
#
#
# bloggername :☆:*:Haniel in wonderland:*:☆
#
#
# link : https://blog.naver.com/angelhaniel
#
#
#
#
# title :[<b>이태원</b>/<b>녹사평</b> <b>맛집</b>] 외쿡의 맛 그대로 '라이너스 바베큐'
#
#
# bloggername :연이로그
#
#
# link : https://blog.naver.com/cosu1212
#
#
#
#
# title :<b>이태원</b> <b>맛집</b>, <b>녹사평</b>역 <b>맛집</b> 라이너스 바베큐
#
#
# bloggername :What We Want
#
#
# link : https://blog.naver.com/kwonsista
#
#
#
#
# title :<b>이태원</b>/<b>녹사평</b><b>맛집</b> : 정통 뉴욕식피자 '지노스피자(GINOS...
#
#
# bloggername :나스나스한하루
#
#
# link : https://blog.naver.com/2vivi
