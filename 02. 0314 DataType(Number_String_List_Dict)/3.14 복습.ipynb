# %%
head = "smart"
tail ="analytics"
fullString = head + tail
print(fullString)
# Out:
# smartanalytics

# %%
head = "yeeun"

# %%
middle="is"

# %%
end="zzang"

# %%
fullSpring=head+middle+end
fullSpring
# Out:
# 'yeeuniszzang'

# %%
print("Yeeuniszzang"*20)
# Out:
# YeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzangYeeuniszzang

# %%
#문자열 곱하기
print("*"*20)
# Out:
# ********************

# %%
#문자열 인덱싱 0부터 시작
yearweek = "201801"

# %%
print(yearweek[0])
print(yearweek[2:])
print(yearweek[4:6])
# Out:
# 2
# 1801
# 01

# %%
#문자열 개수세기 = print(변수.count("세고싶은 변수"))
yearweek = "2017W28"
print(yearweek.count("W"))
# Out:
# 1

# %%
#문자열 위치확인
yearweek = "2017W28"
print(yearweek.index('W'))
delimeter=yearweek.index('W') 
yearweek_new = yearweek[:delimeter]+yearweek[delimeter:]
print([yearweek_new])
# Out:
# 4
# ['2017W28']

# %%
#문자열 위치확인
yearweek = "2017W28"
print(yearweek.index('W'))
delimeter=yearweek.index('W')
# Out:
# 4

# %%
#split 함수
yearweek_list = yearweek.split("4")
print(yearweek_list)
#split 함수
yearweek_list = yearweek.split("2")
print(yearweek_list)
# Out:
# ['2017W28']
# ['', '017W', '8']

# %%
# Out:
# ----------------------------------------------
# NameError    Traceback (most recent call last)
# <ipython-input-5-f4b8a23b3ce7> in <module>()
# ----> 1 print(fullSpring)
#
# NameError: name 'fullSpring' is not defined

# %%
#숫자->문자
numberValue = 1234
cvStrValue = str(numberValue)

# %%
#문자-> 숫자
strValue = "1234"
cvIntValue = int(strValue)

# %%
String = "SEC 20180212 250"
stock_name = print(String[0:3])
# Out:
# SEC

# %%
date = print(String[4:12])
# Out:
# 20180212

# %%
value =print(String[12:])
# Out:
#  250

# %%
Level= "Sec 2018W28 250"
stock_name= Level([0:3])
Stock_name= stock_name.upper()
print(String_name)

# %%
a1=2**3
a1
# Out:
# 8

# %%
b=3%2
b
# Out:
# 1

# %%
import timeit
start = timeit.default_timer()
#Your code start
#Your code end
import pandas as pd
qtyList = pd.read_csv\
("../dataset/kopo_channel_seasonality_new.csv")["QTY"].tolist()
print(qtyList)
stop= timeit.default_timer()
print('Time:',stop-start()
# Out:
#   File "<ipython-input-47-e6cd600e72d0>", line 9
#     print('Time:',stop-start()
#                               ^
# SyntaxError: unexpected EOF while parsing

# %%
import pandas as pd
qtyList = pd.read_csv\
("../dataset/kopo_channel_seasonality_new.csv")["QTY"].tolist()
print(qtyList)
# Out:
# [71.0, 22275.0, 4463.0, 0.0, 23.0, 14.0, 1186.0, 7.0, 101.0, 336.0, 0.0, 11492.0, 825.0, 0.0, 560.0, 103.0, 0.0, 740.0, 394.0, 2550.0, 4.0, 36549.0, 4773.0, 146.0, 5.0, 9.0, 109.0, 1195.0, 15028.0, 1319.0, 786.0, 97.0, 695.0, 3.0, 0.0, 0.0, 484.0, 657.0, 1191.0, 385.0, 21679.0, 879.0, 203.0, 75.0, 1173.0, 1235.0, 156.0, 23768.0, 105.0, 1513.0, 59.0, 4436.0, 4.0, 5449.0, 13394.0, 119281.0, 21350.0, 6940.0, 8022.0, 3823.0, 3697.0, 0.0, 100.0, 3216.0, 1748.0, -1.0, 20184.0, 1404.0, 488.0, 12.0, 107.0, 54.0, 5496.0, 168.0, 885.0, 923.0, 335.0, 1066.0, 11.0, 189.0, 1728.0, 2462.0, 1012.0, 1469.0, 21588.0, 610.0, 226.0, 122.0, 1398.0, 5838.0, 151.0, 383.0, 69.0, 1304.0, 0.0, 32110.0, 920.0, 0.0, 4944.0, 640.0, 2307.0, 12.0, 63255.0, 946.0, 1838.0, 107.0, 208.0, 62.0, 17.0, 8.0, 282.0, 72.0, 1108.0, 984.0, 28102.0, 3225.0, 169.0, 1.0, 7.0, 2414.0, 89.0, 0.0, 0.0, 6787.0, 1303.0, 2489.0, 449.0, 37062.0, 3660.0, 89.0, 0.0, 3850.0, 80.0, 17.0, 58500.0, 3931.0, 7242.0, 0.0, 7128.0, 459.0, 0.0, 
# ...

# %%
min(qtyList)
# Out:
# -364.0

# %%
Sum=(sum(qtyList))
maxValue= max(qtyList)
minValue= min(qtyList)
qtyList.remove(minValue)
qtyList.remove(maxValue)
Sum/len(qtyList)
# Out:
# 8936.234129590708

# %%
sum(qtyList)
# Out:
# 1115600171.19

# %%
len(qtyList)
# Out:
# 124658

# %%
Sum=(sum(qtyList)-max(qtyList)-min(qtyList))
#-가 아니라 revmoe 함수! 
#qtyList.remove(max(qtyList))
qtyList.remove(minValue)

minValue = min(test2)
print(minValue)
maxValue = max(test2)
print(maxValue)

Sum
# Out:
# 1113937329.19

# %%
Answer=Sum/len(qtyList)
Answer
# Out:
# 8935.947385566911

# %%
i="a,b,c"
len(i)
# Out:
# 5

# %%
dic = {"product":"product1","yearweek":"201810","qty":"100"}
dic("qty")
# Out:
# ----------------------------------------------
# TypeError    Traceback (most recent call last)
# <ipython-input-52-0bfb9ae349ee> in <module>()
#       1 dic = {"product":"product1","yearweek":"201810","qty":"100"}
# ----> 2 dic("qty")
#
# TypeError: 'dict' object is not callable

# %%
import

# %%
fintech_love
quiz.split("_")[0]
# Out:
# ----------------------------------------------
# NameError    Traceback (most recent call last)
# <ipython-input-56-6e45685dab4a> in <module>()
# ----> 1 fintech_love
#       2 quiz.split("_")[0]
#
# NameError: name 'fintech_love' is not defined
