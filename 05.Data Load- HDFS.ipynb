# %%
import pandas as pd

# %%
customerData2 = pd.read_csv("../dataset/customerdata.csv")
customerData2
# Out:
# -------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-6-42c027816686> in <module>()
# ----> 1 customerData2 = pd.read_csv("../dataset/customerdata.csv")
#       2 customerData2
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
customerData = pd.DataFrame(customerData)
# Out:
# -------------------------------------------------
# NameError       Traceback (most recent call last)
# <ipython-input-7-cb94389eb999> in <module>()
# ----> 1 customerData = pd.DataFrame(customerData)
#
# NameError: name 'customerData' is not defined

# %%
customerData.head()

# %%
customerData.dtypes #각 컬럼별로 데이타 타입이 나옴

# %%
pwd
# Out:
# 'C:\\Users\\SMART-12\\Python_Fintech'

# %%
pwd
# Out:
# 'C:\\Users\\SMART-12\\Python_Fintech'

# %%
import pandas as pd
customerData = pd.read_csv("C:\Users\SMART-12\Python_Fintech/customerdata.csv")
customerData.head()
# Out:
#   File "<ipython-input-28-da4847d3ce16>", line 2
#     customerData = pd.read_csv("C:\Users\SMART-12\Python_Fintech/customerdata.csv")
#                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
# pd.read_csv("C:\Users\SMART-12\Python_Fintech\dataset/customerdata.csv")
customerData = pd.read_csv("./dataset/kopo_customerdata.csv")
customerData.head()
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# ...

# %%
print(customerData.dtypes)
# Out:
# CUSTOMERCODE      int64
# STATENAME        object
# ST                int64
# GENDER           object
# DOB               int64
# GENDER1           int64
# EMAIL             int64
# FEST_CNT          int64
# TOTAL_AMOUNT      int64
# AC_AMOUNT         int64
# AV_AMOUNT         int64
# HA_AMOUNT         int64
# EMI_CE_AMOUNT     int64
# IS_HIGHEND        int64
# CNT_VIST          int64
# GAP_VISIT         int64
# dtype: object

# %%
answer1 = customerData [(customerData.GENDER=="Male")& (customerData.EMAIL>0)]
answer1
# Out:
#         CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2   Male    0        1      1         0
# 16           1154228    State2   2   Male    0        1      1         0
# 81            393246    State2   2   Male    0        1      1         1
# 206          2532568    State2   2   Male    1        1      1         0
# 216           487928    State2   2   Male    0        1      1         0
# 226          2452240    State2   2   Male    1        1      1         1
# 299          1295854    State2   2   Male    1        1      1         2
# 308           554757    State2   2   Male    0        1      1         0
# 330           761018    State2   2   Male    1        1      1         0
# 367          2191152    State2   2   Male    0        1      1         1
# 375           867914    State2   2   Male    0        1      1         0
# 415          1804886    State2   2   Male    0        1      1         1
# ...

# %%
answer2 = customerData.query('GENDER=="Male" & EMAIL>0')
answer2
# Out:
#         CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2   Male    0        1      1         0
# 16           1154228    State2   2   Male    0        1      1         0
# 81            393246    State2   2   Male    0        1      1         1
# 206          2532568    State2   2   Male    1        1      1         0
# 216           487928    State2   2   Male    0        1      1         0
# 226          2452240    State2   2   Male    1        1      1         1
# 299          1295854    State2   2   Male    1        1      1         2
# 308           554757    State2   2   Male    0        1      1         0
# 330           761018    State2   2   Male    1        1      1         0
# 367          2191152    State2   2   Male    0        1      1         1
# 375           867914    State2   2   Male    0        1      1         0
# 415          1804886    State2   2   Male    0        1      1         1
# ...

# %%
import pandas as pd
# pd.read_csv("C:\Users\SMART-12\Python_Fintech\dataset/customerdata.csv")
customerData = pd.read_csv("./dataset/kopo_product_volume.csv")
customerData.head()
# Out:
#   REGIONID PRODUCTGROUP  YEARWEEK  VOLUME  Unnamed: 4  Unnamed: 5
# 0      A01       ST0001    201501  513598         NaN         NaN
# 1      A01       ST0001    201502  438251         NaN         NaN
# 2      A01       ST0001    201503  420290         NaN         NaN
# 3      A01       ST0001    201504  458431         NaN         NaN
# 4      A01       ST0001    201505  482381         NaN         NaN

# %%
answer3 = customerData [(customerData.PRODUCTGROUP=="ST0002")& (customerData.VOLUME>300000)]
answer3
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME  Unnamed: 4  Unnamed: 5
# 151      A01       ST0002    201547   378339         NaN         NaN
# 152      A01       ST0002    201548  1400339         NaN         NaN
# 153      A01       ST0002    201549   669711         NaN         NaN
# 155      A01       ST0002    201551   356271         NaN         NaN
# 156      A01       ST0002    201552   422468         NaN         NaN
# 203      A01       ST0002    201646   441993         NaN         NaN
# 204      A01       ST0002    201647  1663206         NaN         NaN
# 205      A01       ST0002    201648   711806         NaN         NaN
# 207      A01       ST0002    201650   320253         NaN         NaN
# 208      A01       ST0002    201651   401602         NaN         NaN
